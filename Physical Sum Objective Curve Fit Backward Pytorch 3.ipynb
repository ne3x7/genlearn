# %%
import numpy as np
import pandas as pd

import torch
import torch.nn as nn
import torch.optim as optim

from torchdiffeq import odeint_adjoint as odeint

import os
import sys

import IPython.display as dp
import matplotlib.pyplot as plt
import seaborn as sns

dp.set_matplotlib_formats('retina')
sns.set_style('whitegrid')
sns.despine()

# %matplotlib notebook

# %% [markdown]
# ## Neural ODE

# %%
def get_initial_values(P0, Q0, V0, angle0, theta0, Sn=2220, Vn=400, fn=60, Sb=100, Vb=400):
    """
    Initializes generator state vector `x` and network terminal variables vector `V`
    in machine base from given power flow values in system base and angle in radians.
    """
    
    # unpack parameters guess
    ws = 1
    KD = 0
    ra, x1d, xd, xq, H, T1d0, Kw, Tw, Tpss1, Tpss2, Tr, Tavr1, Tavr2, Te, K0 = theta0
    
    # define transforms
    
    # vf_MB = vf * Vb / Vn
    wb = 2 * np.pi * fn
    S_SBtoMB = Sb / Sn
    V_MBtoSB = Vn / Vb
    I_MBtoSB = Sn * Vb / (Sb * Vn)
    Z_MBtoSB = Sb * Vn ** 2 / (Sn * Vb ** 2)
    
    # initialize stator quantitites
    
    p0 = P0 / Sb
    q0 = Q0 / Sb
    Vt0 = V0 * np.exp(1j * angle0)
    S0 = p0 - 1j * q0
    I0 = S0 / Vt0.conjugate()
    vr0 = Vt0.real
    vi0 = Vt0.imag
    ir0 = -I0.real
    ii0 = -I0.imag
    
    # initialize DQ-quantities
    
    w0 = 1
    delta0 = np.angle(Vt0 + (ra + 1j * xq) * Z_MBtoSB * I0)
    
    Vdq0 = Vt0 * (1 / V_MBtoSB) * np.exp(1j * (-delta0 + np.pi/2))
    Idq0 = I0 * (1 / I_MBtoSB) * np.exp(1j * (-delta0 + np.pi/2))
    
    vd0 = Vdq0.real
    vq0 = Vdq0.imag
    id0 = Idq0.real
    iq0 = Idq0.imag
    
    # initialize order 3
    
    e1q0 = vq0 + ra * iq0 + x1d * id0
    
    # initialize AVR
    
    v = np.abs(Vt0)
    vref = v
    vs0 = 0
    vm0 = v
    vf0 = (e1q0 + (xd - x1d) * id0) * V_MBtoSB
    vr0 = K0 * (1 - Tavr1 / Tavr2) * (vref + vs0 - vm0)
    
    # initialize PSS
    
    v20 = 0
    
    # constants
    
    pm = (vq0 + ra * iq0) * iq0 + (vd0 + ra * id0) * id0
    vsmin, vsmax = -0.2, 0.2
    vfmin, vfmax = -6.4, 7
    
    # pack values
    
    x = np.array([delta0, w0, v20, vs0, vm0, vr0, vf0, e1q0])
    V = np.array([vd0, vq0, id0, iq0])
    c = np.array([pm, vsmin, vsmax, vfmin, vfmax, vref, vf0, vs0, wb, KD])
    
    return x, V, c, (p0, q0)

# %%
class RHSTrue(nn.Module):
    def __init__(self, v, c, t):
        super(RHSTrue, self).__init__()
        
        self.theta = torch.from_numpy(np.array([0.003, 0.3, 1.81, 1.76, 3.5, 8.,
                                                10., 10., 0.05, 0.02, 0.015, 1.,
                                                1., 0.0001, 200]))
        self.c = c
        self.vt = lambda x: np.interp(x, t, v[:, 0])
        self.phi = lambda x: np.interp(x, t, v[:, 1])
        
    def forward(self, t, x):
        v = torch.tensor([self.vt(t), self.phi(t)])

        vd = v[0] * torch.sin(x[0] - v[1])
        vq = v[0] * torch.cos(x[0] - v[1])

        id = (self.theta[3] * x[7] - self.theta[3] * vq - self.theta[0] * vd) / (self.theta[1] * self.theta[3] + self.theta[0] ** 2)
        iq = (self.theta[0] * x[7] - self.theta[0] * vq + self.theta[1] * vd) / (self.theta[1] * self.theta[3] + self.theta[0] ** 2)

        p = 22.2 * (vd * id + vq * iq)
        q = 22.2 * (vq * id - vd * iq)
        
        pe = (vq + self.theta[0] * iq) * iq + (vd + self.theta[0] * id) * id

        return torch.stack([
            self.c[8] * (x[1] - 1),
            (self.c[0] - pe) / (2 * self.theta[4]),
            self.theta[6] * (self.c[0] - pe) / (2 * self.theta[4]) - x[2] / self.theta[7],
            (self.theta[8] * (self.theta[6] * (self.c[0] - pe)
                              / (2 * self.theta[4]) - x[2]
                              / self.theta[7]) + x[2] - x[3]) / self.theta[9],
            (v[0] - x[4]) / self.theta[10],
            (self.theta[14] * (1 - self.theta[11] / self.theta[12]) * (self.c[5] + x[3] - x[4]) - x[5]) / self.theta[12],
            ((x[5] + self.theta[14] * self.theta[11] * (self.c[5] + x[3] - x[4])
              / self.theta[12] + self.c[6]) * (1 + self.c[7] * (v[0] / x[4] - 1)) - x[6]) / self.theta[13],
            (- x[7] - (self.theta[2] - self.theta[1]) * id + x[6]) / self.theta[5]
        ])

# %%
class RHS(nn.Module):
    def __init__(self, v, c, t):
        super(RHS, self).__init__()
        
        self.theta = nn.Parameter(torch.rand(15))
        self.s = torch.from_numpy(np.array([0.01, 1., 10., 10., 10., 10.,
                                            10., 10., 0.1, 0.1, 0.1, 1.,
                                            1., 0.001, 1000]))
        self.c = c
        self.vt = lambda x: np.interp(x.detach().numpy(), t.detach().numpy(), v[:, 0])
        self.phi = lambda x: np.interp(x.detach().numpy(), t.detach().numpy(), v[:, 1])
        
    def forward(self, t, x):
        v = torch.tensor([self.vt(t), self.phi(t)])

        vd = v[0] * torch.sin(x[0] - v[1])
        vq = v[0] * torch.cos(x[0] - v[1])

        id = (self.s[3] * self.theta[3] * x[7] - self.s[3] * self.theta[3] * vq - self.s[0] * self.theta[0] * vd) / (self.s[1] * self.theta[1] * self.s[3] * self.theta[3] + (self.s[0] * self.theta[0]) ** 2)
        iq = (self.s[0] * self.theta[0] * x[7] - self.s[0] * self.theta[0] * vq + self.s[1] * self.theta[1] * vd) / (self.s[1] * self.theta[1] * self.s[3] * self.theta[3] + (self.s[0] * self.theta[0]) ** 2)
        p = 22.2 * (vd * id + vq * iq)
        q = 22.2 * (vq * id - vd * iq)
        
        pe = (vq + self.s[0] * self.theta[0] * iq) * iq + (vd + self.s[0] * self.theta[0] * id) * id

        return torch.stack([
            self.c[8] * (x[1] - 1),
            (self.c[0] - pe) / (2 * self.s[4] * self.theta[4]),
            self.s[6] * self.theta[6] * (self.c[0] - pe) / (2 * self.s[4] * self.theta[4]) - x[2] / (self.s[7] * self.theta[7]),
            (self.s[8] * self.theta[8] * (self.s[6] * self.theta[6] * (self.c[0] - pe)
                              / (2 * self.s[4] * self.theta[4]) - x[2]
                              / (self.s[7] * self.theta[7])) + x[2] - x[3]) / (self.s[9] * self.theta[9]),
            (v[0] - x[4]) / (self.s[10] * self.theta[10]),
            (self.s[14] * self.theta[14] * (1 - self.s[11] * self.theta[11] / (self.s[12] * self.theta[12])) * (self.c[5] + x[3] - x[4]) - x[5]) / (self.s[12] * self.theta[12]),
            ((x[5] + self.s[14] * self.theta[14] * self.s[11] * self.theta[11] * (self.c[5] + x[3] - x[4])
              / (self.s[12] * self.theta[12]) + self.c[6]) * (1 + self.c[7] * (v[0] / x[4] - 1)) - x[6]) / (self.s[13] * self.theta[13]),
            (- x[7] - (self.s[2] * self.theta[2] - self.s[1] * self.theta[1]) * id + x[6]) / (self.s[5] * self.theta[5])
        ])

# %%
data_size = 60001
batch_time = 5000
batch_size = 1
t = torch.linspace(0, 6, steps=data_size)
# df = pd.read_csv('./exportedVariables.csv')
df = pd.read_csv('./exportedVariables2.csv')
df = df.drop_duplicates('time')
df = df.drop(['time'], axis=1)
# df.columns = ['p', 'q', 'v', 'phi']
df.columns = ['v', 'vm', 'vr', 'p', 'q', 'phi', 'delta',
              'e1q', 'id', 'iq', 'ii', 'ir', 'vi', 'vrr',
              'vd', 'vf', 'vq', 'w', 'vs']
df = df.drop(['ii', 'ir', 'vi', 'vrr', 'vd', 'vq', 'id', 'iq'], axis=1)
df.phi = df.phi * np.pi / 180
v = df[['v', 'phi']].values
x0, v0, c, (p0, q0) = get_initial_values(P0=1997.9999999936396,
                                         Q0=967.9249699065775,
                                         V0=1.0,
                                         angle0=0.494677176989154,
                                         theta0=np.array([0.003, 0.3, 1.81, 1.76, 3.5, 8.,
                                                          10., 10., 0.05, 0.02, 0.015, 1.,
                                                          1., 0.0001, 200]))
with torch.no_grad():
    rhs_true = RHSTrue(v, c, t)
    true_y = odeint(rhs_true, torch.from_numpy(x0), t, method='euler')

# %%
deltas = true_y[:, 0]
e1qs = true_y[:, -1]
pqs = []
for delta, e1q, vt, phi in zip(deltas, e1qs, df.v, df.phi):
    vd = vt * np.sin(delta - phi)
    vq = vt * np.cos(delta - phi)
    
    id = (1.76 * e1q - 1.76 * vq - 0.003 * vd) / (0.3 * 1.76 + 0.003 ** 2)
    iq = (0.003 * e1q - 0.003 * vq + 0.3 * vd) / (0.3 * 1.76 + 0.003 ** 2)
    
    p = 22.2 * (vd * id + vq * iq)
    q = 22.2 * (vq * id - vd * iq)
    pqs.append([p, q])
pqs = np.array(pqs)

# %%
plt.plot(df.q)
plt.plot(pqs[:, 1])

# %%
def get_batch_size_one():
    s = np.random.choice(np.arange(data_size - batch_time, dtype=np.int64), replace=False)
    batch_y0 = true_y[s]  # (M, D)
    batch_t = t[s:s+batch_time]  # (T)
    batch_y = torch.stack([true_y[s + i] for i in range(batch_time)], dim=0)  # (T, M, D)
    return batch_y0, batch_t, batch_y

def get_batch():
    s = torch.from_numpy(np.random.choice(np.arange(data_size - batch_time, dtype=np.int64), batch_size, replace=False))
    batch_y0 = true_y[s]  # (M, D)
    batch_t = t[s:s+batch_time]  # (T)
    batch_y = torch.stack([true_y[s + i] for i in range(batch_time)], dim=0)  # (T, M, D)
    return batch_y0, batch_t, batch_y

# %%
rhs = RHS(v, c, t)
rhs.double()
optimizer = optim.RMSprop(rhs.parameters())
for iter_n in range(100):
    theta_prev = rhs.theta.clone()
    optimizer.zero_grad()
    batch_y0, batch_t, batch_y = get_batch_size_one()
    pred_y = odeint(rhs, batch_y0, batch_t, method='euler')
    loss = (pred_y - batch_y).pow(2).sum()
    loss.backward()
    optimizer.step()
    for param in rhs.parameters():
        param.data.clamp_(min=1e-1, max=1)
    reference = (rhs.theta - torch.from_numpy(np.array([0.003, 0.3, 1.81, 1.76, 3.5, 8.,
                                                        10., 10., 0.05, 0.02, 0.015, 1.,
                                                        1., 0.0001, 200])) / rhs.s).pow(2).sum().sqrt().item()
    # dist = (rhs.theta - theta_prev).pow(2).sum().sqrt().item()
    print('[%04d]\tloss\t%e\tdistance to solution\t%e' % (iter_n, loss.item(), reference))
# Out:
# [0000]	loss	7.771538e+05	distance to solution	1.989955e+00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-50b427eb111c> in <module>()
#       6     optimizer.zero_grad()
#       7     batch_y0, batch_t, batch_y = get_batch_size_one()
# ----> 8     pred_y = odeint(rhs, batch_y0, batch_t, method='euler')
#       9     loss = (pred_y - batch_y).pow(2).sum()
#      10     loss.backward()
#
# ~/.virtualenvs/torch1venv3/lib/python3.6/site-packages/torchdiffeq/_impl/adjoint.py in odeint_adjoint(func, y0, t, rtol, atol, method, options)
#     127
#     128     flat_params = _flatten(func.parameters())
# --> 129     ys = OdeintAdjointMethod.apply(*y0, func, t, flat_params, rtol, atol, method, options)
#     130
#     131     if tensor_input:
#
# ~/.virtualenvs/torch1venv3/lib/python3.6/site-packages/torchdiffeq/_impl/adjoint.py in forward(ctx, *args)
#      16
#      17         with torch.no_grad():
# ---> 18             ans = odeint(func, y0, t, rtol=rtol, atol=atol, method=method, options=options)
#      19         ctx.save_for_backward(t, flat_params, *ans)
#      20         return ans
#
# ~/.virtualenvs/torch1venv3/lib/python3.6/site-packages/torchdiffeq/_impl/odeint.py in odeint(func, y0, t, rtol, atol, method, options)
#      70
#      71     solver = SOLVERS[method](func, y0, rtol=rtol, atol=atol, **options)
# ---> 72     solution = solver.integrate(t)
#      73
#      74     if tensor_input:
#
# ~/.virtualenvs/torch1venv3/lib/python3.6/site-packages/torchdiffeq/_impl/solvers.py in integrate(self, t)
#      89         y0 = self.y0
#      90         for t0, t1 in zip(time_grid[:-1], time_grid[1:]):
# ---> 91             dy = self.step_func(self.func, t0, t1 - t0, y0)
#      92             y1 = tuple(y0_ + dy_ for y0_, dy_ in zip(y0, dy))
#      93             y0 = y1
#
# ~/.virtualenvs/torch1venv3/lib/python3.6/site-packages/torchdiffeq/_impl/fixed_grid.py in step_func(self, func, t, dt, y)
#       6
#       7     def step_func(self, func, t, dt, y):
# ----> 8         return tuple(dt * f_ for f_ in func(t, y))
#       9
#      10     @property
#
# ~/.virtualenvs/torch1venv3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# ~/.virtualenvs/torch1venv3/lib/python3.6/site-packages/torchdiffeq/_impl/adjoint.py in forward(self, t, y)
#     120
#     121             def forward(self, t, y):
# --> 122                 return (self.base_func(t, y[0]),)
#     123
#     124         tensor_input = True
#
# ~/.virtualenvs/torch1venv3/lib/python3.6/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     487             result = self._slow_forward(*input, **kwargs)
#     488         else:
# --> 489             result = self.forward(*input, **kwargs)
#     490         for hook in self._forward_hooks.values():
#     491             hook_result = hook(self, input, result)
#
# <ipython-input-4-9746da072d76> in forward(self, t, x)
#      34             (self.s[14] * self.theta[14] * (1 - self.s[11] * self.theta[11] / (self.s[12] * self.theta[12])) * (self.c[5] + x[3] - x[4]) - x[5]) / (self.s[12] * self.theta[12]),
#      35             ((x[5] + self.s[14] * self.theta[14] * self.s[11] * self.theta[11] * (self.c[5] + x[3] - x[4])
# ---> 36               / (self.s[12] * self.theta[12]) + self.c[6]) * (1 + self.c[7] * (v[0] / x[4] - 1)) - x[6]) / (self.s[13] * self.theta[13]),
#      37             (- x[7] - (self.s[2] * self.theta[2] - self.s[1] * self.theta[1]) * id + x[6]) / (self.s[5] * self.theta[5])
#      38         ])
#
# KeyboardInterrupt:

# %%
for iter_n in range(1000):
    theta_prev = rhs.theta.clone()
    optimizer.zero_grad()
    batch_y0, batch_t, batch_y = get_batch_size_one()
    pred_y = odeint(rhs, batch_y0, batch_t, method='euler')
    loss = (pred_y - batch_y).pow(2).sum()
    loss.backward()
    optimizer.step()
    for param in rhs.parameters():
        param.data.clamp_(min=1e-1, max=1)
    reference = (rhs.theta - torch.from_numpy(np.array([0.003, 0.3, 1.81, 1.76, 3.5, 8.,
                                                        10., 10., 0.05, 0.02, 0.015, 1.,
                                                        1., 0.0001, 200])) / rhs.s).pow(2).sum().sqrt().item()
    # dist = (rhs.theta - theta_prev).pow(2).sum().sqrt().item()
    print('[%04d]\tloss\t%e\tdistance to solution\t%e' % (iter_n, loss.item(), reference))
# Out:
# [0000]	loss	1.302833e+01	distance to solution	1.419892e+00
# [0001]	loss	3.280174e+00	distance to solution	1.419795e+00
# [0002]	loss	6.010175e-01	distance to solution	1.419908e+00
# [0003]	loss	4.871973e-01	distance to solution	1.419946e+00
# [0004]	loss	1.897405e-01	distance to solution	1.419905e+00
# [0005]	loss	9.240494e-02	distance to solution	1.419936e+00
# [0006]	loss	1.326901e+01	distance to solution	1.419559e+00
# [0007]	loss	7.072579e+00	distance to solution	1.419092e+00
# [0008]	loss	6.368595e+01	distance to solution	1.418007e+00
# [0009]	loss	4.535810e+01	distance to solution	1.419548e+00
# [0010]	loss	1.078237e+01	distance to solution	1.418968e+00
# [0011]	loss	4.615867e+00	distance to solution	1.419085e+00
# [0012]	loss	1.166033e+00	distance to solution	1.419004e+00
# [0013]	loss	4.378177e+02	distance to solution	1.419800e+00
# [0014]	loss	4.897506e+02	distance to solution	1.416390e+00
# [0015]	loss	2.764019e+02	distance to solution	1.420586e+00
# [0016]	loss	9.476992e+01	distance to solution	1.418852e+00
# [0017]	loss	6.419581e+01	distance to solution	1.420072e+00
# [0018]	loss	8.017653e+01	distance to solution	1.418269e+00
# [0019]	loss	1.238789e+01	distance to solution	1.418708e+00
# [0020]	loss	3.193774e+00	distance to solution	1.418569e+00
# [0021]	loss	2.534925e+01	distance to solution	1.417670e+00
# [0022]	loss	2.388636e+01	distance to solution	1.417776e+00
# [0957]	loss	3.531544e+01	distance to solution	1.132058e+00
# [0958]	loss	3.448064e+01	distance to solution	1.130329e+00
# [0959]	loss	3.322824e+01	distance to solution	1.132451e+00
# [0960]	loss	4.253035e+01	distance to solution	1.132093e+00
# [0961]	loss	1.510767e+03	distance to solution	1.140688e+00
# [0962]	loss	3.737154e+03	distance to solution	1.129786e+00
# [0963]	loss	4.389808e+03	distance to solution	1.174740e+00
# [0964]	loss	5.136949e+00	distance to solution	1.175290e+00
# [0965]	loss	3.271464e+01	distance to solution	1.176341e+00
# [0966]	loss	3.055331e+01	distance to solution	1.177213e+00
# [0967]	loss	5.481769e+00	distance to solution	1.177188e+00
# [0968]	loss	2.198241e-01	distance to solution	1.177127e+00
# [0969]	loss	1.952573e-01	distance to solution	1.177049e+00
# [0970]	loss	4.148726e-02	distance to solution	1.177065e+00
# [0971]	loss	4.033008e-02	distance to solution	1.177040e+00
# [0972]	loss	7.526805e-01	distance to solution	1.177226e+00
# [0973]	loss	1.289108e+01	distance to solution	1.176540e+00
# [0974]	loss	4.173566e+01	distance to solution	1.175924e+00
# [0975]	loss	1.963249e+01	distance to solution	1.179278e+00
# [0976]	loss	4.604200e+02	distance to solution	1.181334e+00
# [0977]	loss	4.540319e+02	distance to solution	1.195741e+00
# [0978]	loss	3.944657e-01	distance to solution	1.195772e+00
# [0979]	loss	1.186694e+01	distance to solution	1.195717e+00
# [0980]	loss	6.394129e+00	distance to solution	1.195955e+00
# [0981]	loss	5.549379e-01	distance to solution	1.195742e+00
# [0982]	loss	1.249328e+00	distance to solution	1.195888e+00
# [0983]	loss	3.421903e+00	distance to solution	1.195562e+00
# [0984]	loss	1.602392e+00	distance to solution	1.195910e+00
# [0985]	loss	1.184913e+03	distance to solution	1.202819e+00
# [0986]	loss	1.153752e+03	distance to solution	1.201829e+00
# [0987]	loss	4.732737e+02	distance to solution	1.213119e+00
# [0988]	loss	7.677938e+01	distance to solution	1.210176e+00
# [0989]	loss	4.079136e+00	distance to solution	1.210322e+00
# [0990]	loss	1.087040e+01	distance to solution	1.209042e+00
# [0991]	loss	8.733281e+00	distance to solution	1.208691e+00
# [0992]	loss	2.211564e+00	distance to solution	1.207995e+00
# [0993]	loss	6.871675e+00	distance to solution	1.208362e+00
# [0994]	loss	1.330231e+01	distance to solution	1.207748e+00
# [0995]	loss	5.752920e+02	distance to solution	1.195777e+00
# [0996]	loss	2.324435e+01	distance to solution	1.196241e+00
# [0997]	loss	1.104460e+00	distance to solution	1.196091e+00
# [0998]	loss	8.960424e-02	distance to solution	1.196071e+00
# [0999]	loss	5.356132e-02	distance to solution	1.196097e+00

# %%
with torch.no_grad():
    pred_y = odeint(rhs, torch.from_numpy(x0), t, method='euler')

deltas = pred_y[:, 0]
e1qs = pred_y[:, -1]
pqs = []
for delta, e1q, vt, phi in zip(deltas, e1qs, df.v, df.phi):
    vd = vt * np.sin(delta - phi)
    vq = vt * np.cos(delta - phi)
    
    id = (1.76 * e1q - 1.76 * vq - 0.003 * vd) / (0.3 * 1.76 + 0.003 ** 2)
    iq = (0.003 * e1q - 0.003 * vq + 0.3 * vd) / (0.3 * 1.76 + 0.003 ** 2)
    
    p = 22.2 * (vd * id + vq * iq)
    q = 22.2 * (vq * id - vd * iq)
    pqs.append([p, q])
pqs = np.array(pqs)

# %%
plt.plot(df.p, label='true')
plt.plot(pqs[:, 0], label='pred')
plt.legend()

# %%
import dill as pickle

# %%
with open('rhs_optimizer.pkl', 'wb') as f:
    pickle.dump((rhs, optimizer), f)

# %% [markdown]
# ## Modified

# %%
from modules.torchdiffeq.torchdiffeq import odeint_adjoint

# %%
class RHSTrue(nn.Module):
    def __init__(self, c):
        super(RHSTrue, self).__init__()
        
        self.theta = torch.from_numpy(np.array([0.003, 0.3, 1.81, 1.76, 3.5, 8.,
                                                10., 10., 0.05, 0.02, 0.015, 1.,
                                                1., 0.0001, 200]))
        self.c = c
        
    def forward(self, t, x, v):
        vd = v[:, 0] * torch.sin(x[:, 0] - v[:, 1])
        vq = v[:, 0] * torch.cos(x[:, 0] - v[:, 1])

        id = (self.theta[3] * x[:, 7] - self.theta[3] * vq - self.theta[0] * vd) / (self.theta[1] * self.theta[3] + self.theta[0] ** 2)
        iq = (self.theta[0] * x[:, 7] - self.theta[0] * vq + self.theta[1] * vd) / (self.theta[1] * self.theta[3] + self.theta[0] ** 2)

        p = 22.2 * (vd * id + vq * iq)
        q = 22.2 * (vq * id - vd * iq)
        
        pe = (vq + self.theta[0] * iq) * iq + (vd + self.theta[0] * id) * id

        return torch.stack([
            self.c[8] * (x[:, 1] - 1),
            (self.c[0] - pe) / (2 * self.theta[4]),
            self.theta[6] * (self.c[0] - pe) / (2 * self.theta[4]) - x[:, 2] / self.theta[7],
            (self.theta[8] * (self.theta[6] * (self.c[0] - pe)
                              / (2 * self.theta[4]) - x[:, 2]
                              / self.theta[7]) + x[:, 2] - x[:, 3]) / self.theta[9],
            (v[:, 0] - x[:, 4]) / self.theta[10],
            (self.theta[14] * (1 - self.theta[11] / self.theta[12]) * (self.c[5] + x[:, 3] - x[:, 4]) - x[:, 5]) / self.theta[12],
            ((x[:, 5] + self.theta[14] * self.theta[11] * (self.c[5] + x[:, 3] - x[:, 4])
              / self.theta[12] + self.c[6]) * (1 + self.c[7] * (v[:, 0] / x[:, 4] - 1)) - x[:, 6]) / self.theta[13],
            (- x[:, 7] - (self.theta[2] - self.theta[1]) * id + x[:, 6]) / self.theta[5]
        ], dim=1)

# %%
class RHS(nn.Module):
    def __init__(self, c):
        super(RHS, self).__init__()
        
        self.theta = nn.Parameter(torch.rand(15))
        self.s = torch.from_numpy(np.array([0.01, 1., 10., 10., 10., 10.,
                                            10., 10., 0.1, 0.1, 0.1, 1.,
                                            1., 0.001, 1000]))
        self.c = c
        
    def forward(self, t, x, v):
        vd = v[:, 0] * torch.sin(x[:, 0] - v[:, 1])
        vq = v[:, 0] * torch.cos(x[:, 0] - v[:, 1])

        id = (self.s[3] * self.theta[3] * x[:, 7] - self.s[3] * self.theta[3] * vq - self.s[0] * self.theta[0] * vd) / (self.s[1] * self.theta[1] * self.s[3] * self.theta[3] + (self.s[0] * self.theta[0]) ** 2)
        iq = (self.s[0] * self.theta[0] * x[:, 7] - self.s[0] * self.theta[0] * vq + self.s[1] * self.theta[1] * vd) / (self.s[1] * self.theta[1] * self.s[3] * self.theta[3] + (self.s[0] * self.theta[0]) ** 2)
        p = 22.2 * (vd * id + vq * iq)
        q = 22.2 * (vq * id - vd * iq)
        
        pe = (vq + self.s[0] * self.theta[0] * iq) * iq + (vd + self.s[0] * self.theta[0] * id) * id

        return torch.stack([
            self.c[8] * (x[:, 1] - 1),
            (self.c[0] - pe) / (2 * self.s[4] * self.theta[4]),
            self.s[6] * self.theta[6] * (self.c[0] - pe) / (2 * self.s[4] * self.theta[4]) - x[:, 2] / (self.s[7] * self.theta[7]),
            (self.s[8] * self.theta[8] * (self.s[6] * self.theta[6] * (self.c[0] - pe)
                              / (2 * self.s[4] * self.theta[4]) - x[:, 2]
                              / (self.s[7] * self.theta[7])) + x[:, 2] - x[:, 3]) / (self.s[9] * self.theta[9]),
            (v[:, 0] - x[:, 4]) / (self.s[10] * self.theta[10]),
            (self.s[14] * self.theta[14] * (1 - self.s[11] * self.theta[11] / (self.s[12] * self.theta[12])) * (self.c[5] + x[:, 3] - x[:, 4]) - x[:, 5]) / (self.s[12] * self.theta[12]),
            ((x[:, 5] + self.s[14] * self.theta[14] * self.s[11] * self.theta[11] * (self.c[5] + x[:, 3] - x[:, 4])
              / (self.s[12] * self.theta[12]) + self.c[6]) * (1 + self.c[7] * (v[:, 0] / x[:, 4] - 1)) - x[:, 6]) / (self.s[13] * self.theta[13]),
            (- x[:, 7] - (self.s[2] * self.theta[2] - self.s[1] * self.theta[1]) * id + x[:, 6]) / (self.s[5] * self.theta[5])
        ], dim=1)

# %%
data_size = 60001
batch_time = 5000
batch_size = 1
t = torch.linspace(0, 6, steps=data_size)
# df = pd.read_csv('./exportedVariables.csv')
df = pd.read_csv('./exportedVariables2.csv')
df = df.drop_duplicates('time')
df = df.drop(['time'], axis=1)
# df.columns = ['p', 'q', 'v', 'phi']
df.columns = ['v', 'vm', 'vr', 'p', 'q', 'phi', 'delta',
              'e1q', 'id', 'iq', 'ii', 'ir', 'vi', 'vrr',
              'vd', 'vf', 'vq', 'w', 'vs']
df = df.drop(['ii', 'ir', 'vi', 'vrr', 'vd', 'vq', 'id', 'iq'], axis=1)
df.phi = df.phi * np.pi / 180
v = df[['v', 'phi']].values
x0, v0, c, (p0, q0) = get_initial_values(P0=1997.9999999936396,
                                         Q0=967.9249699065775,
                                         V0=1.0,
                                         angle0=0.494677176989154,
                                         theta0=np.array([0.003, 0.3, 1.81, 1.76, 3.5, 8.,
                                                          10., 10., 0.05, 0.02, 0.015, 1.,
                                                          1., 0.0001, 200]))
with torch.no_grad():
    rhs_true = RHSTrue(c)
    true_y = odeint_adjoint(rhs_true, torch.from_numpy(x0[None]), torch.from_numpy(v[:, None, :]), t, method='euler').squeeze(1)

# %%
deltas = true_y[:, 0]
e1qs = true_y[:, -1]
pqs = []
for delta, e1q, vt, phi in zip(deltas, e1qs, df.v, df.phi):
    vd = vt * np.sin(delta - phi)
    vq = vt * np.cos(delta - phi)
    
    id = (1.76 * e1q - 1.76 * vq - 0.003 * vd) / (0.3 * 1.76 + 0.003 ** 2)
    iq = (0.003 * e1q - 0.003 * vq + 0.3 * vd) / (0.3 * 1.76 + 0.003 ** 2)
    
    p = 22.2 * (vd * id + vq * iq)
    q = 22.2 * (vq * id - vd * iq)
    pqs.append([p, q])
pqs = np.array(pqs)

# %%
x0[3], x0[6]
# Out:
# (0.0, 2.4207016420769225)

# %%
plt.plot(df.q)
plt.plot(pqs[:, 1], '--')

# %%
exog_y = torch.from_numpy(v)

# %%
def get_batch():
    s = torch.from_numpy(np.random.choice(np.arange(data_size - batch_time, dtype=np.int64), batch_size, replace=False))
    batch_y0 = true_y[s]  # (M, D)
    batch_t = t[:batch_time]  # (T)
    batch_y = torch.stack([true_y[s + i] for i in range(batch_time)], dim=0)  # (T, M, D)
    batch_y_exog = torch.stack([exog_y[s + i] for i in range(batch_time)], dim=0)  # (T, M, D)
    return batch_y0, batch_t, batch_y, batch_y_exog

# %%
rhs = RHS(c)
rhs.double()
optimizer = optim.RMSprop(rhs.parameters())
for iter_n in range(1000):
    theta_prev = rhs.theta.clone()
    optimizer.zero_grad()
    batch_y0, batch_t, batch_y, batch_y_exog = get_batch()
    pred_y = odeint_adjoint(rhs, batch_y0, batch_y_exog, batch_t, method='euler')
    loss = (pred_y - batch_y).pow(2).sum()
    loss.backward()
    optimizer.step()
    for param in rhs.parameters():
        param.data.clamp_(min=1e-1, max=1)
    reference = (rhs.theta - torch.from_numpy(np.array([0.003, 0.3, 1.81, 1.76, 3.5, 8.,
                                                        10., 10., 0.05, 0.02, 0.015, 1.,
                                                        1., 0.0001, 200])) / rhs.s).pow(2).sum().sqrt().item()
    # dist = (rhs.theta - theta_prev).pow(2).sum().sqrt().item()
    print('[%04d]\tloss\t%e\tdistance to solution\t%e' % (iter_n, loss.item(), reference))
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-60-4da57de019e6> in <module>()
#       8     pred_y = odeint_adjoint(rhs, batch_y0, batch_y_exog, batch_t, method='euler')
#       9     loss = (pred_y - batch_y).pow(2).sum()
# ---> 10     loss.backward()
#      11     optimizer.step()
#      12     for param in rhs.parameters():
#
# ~/.virtualenvs/torch1venv3/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     100                 products. Defaults to ``False``.
#     101         """
# --> 102         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     103
#     104     def register_hook(self, hook):
#
# ~/.virtualenvs/torch1venv3/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      88     Variable._execution_engine.run_backward(
#      89         tensors, grad_tensors, retain_graph, create_graph,
# ---> 90         allow_unreachable=True)  # allow_unreachable flag
#      91
#      92
#
# ~/.virtualenvs/torch1venv3/lib/python3.6/site-packages/torch/autograd/function.py in apply(self, *args)
#      74
#      75     def apply(self, *args):
# ---> 76         return self._forward_cls.backward(self, *args)
#      77
#      78
#
# ~/Desktop/Work/GenLearn/modules/torchdiffeq/torchdiffeq/_impl/adjoint.py in backward(ctx, *grad_output)
#      87                     torch.stack([t[i], t[i - 1]]),
#      88                     torch.stack([y_exog[i], y_exog[i-1]]),
# ---> 89                     rtol=rtol, atol=atol, method=method, options=options
#      90                 )
#      91
#
# ~/Desktop/Work/GenLearn/modules/torchdiffeq/torchdiffeq/_impl/odeint.py in odeint(func, y0, t, y_exog, rtol, atol, method, options)
#      70
#      71     solver = SOLVERS[method](func, y0, y_exog, rtol=rtol, atol=atol, **options)
# ---> 72     solution = solver.integrate(t)
#      73
#      74     if tensor_input:
#
# ~/Desktop/Work/GenLearn/modules/torchdiffeq/torchdiffeq/_impl/solvers.py in integrate(self, t)
#      97         for t0, t1 in zip(time_grid[:-1], time_grid[1:]):
#      98             dy = self.step_func(self.func, t0, t1 - t0, y0, self.y_exog[j])
# ---> 99             y1 = tuple(process(y0_ + dy_) for y0_, dy_ in zip(y0, dy))
#     100             y0 = y1
#     101
#
# ~/Desktop/Work/GenLearn/modules/torchdiffeq/torchdiffeq/_impl/solvers.py in <genexpr>(.0)
#      97         for t0, t1 in zip(time_grid[:-1], time_grid[1:]):
#      98             dy = self.step_func(self.func, t0, t1 - t0, y0, self.y_exog[j])
# ---> 99             y1 = tuple(process(y0_ + dy_) for y0_, dy_ in zip(y0, dy))
#     100             y0 = y1
#     101
#
# ~/Desktop/Work/GenLearn/modules/torchdiffeq/torchdiffeq/_impl/solvers.py in process(x)
#       4
#       5 def process(x):
# ----> 6     x.data[:, 3].clamp_(-0.2, 0.2)
#       7     x.data[:, 6].clamp_(-6.4, 7)
#       8
#
# IndexError: too many indices for tensor of dimension 1

# %%
with torch.no_grad():
    pred_y = odeint_adjoint(rhs, torch.from_numpy(x0[None]), torch.from_numpy(v[:, None, :]), t, method='euler').squeeze(1)

deltas = pred_y[:, 0]
e1qs = pred_y[:, -1]
pqs = []
for delta, e1q, vt, phi in zip(deltas, e1qs, df.v, df.phi):
    vd = vt * np.sin(delta - phi)
    vq = vt * np.cos(delta - phi)
    
    id = (1.76 * e1q - 1.76 * vq - 0.003 * vd) / (0.3 * 1.76 + 0.003 ** 2)
    iq = (0.003 * e1q - 0.003 * vq + 0.3 * vd) / (0.3 * 1.76 + 0.003 ** 2)
    
    p = 22.2 * (vd * id + vq * iq)
    q = 22.2 * (vq * id - vd * iq)
    pqs.append([p, q])
pqs = np.array(pqs)

# %%
plt.plot(df.p)
plt.plot(pqs[:, 0], '--')

# %%
batch_time = 10000
for iter_n in range(500):
    theta_prev = rhs.theta.clone()
    optimizer.zero_grad()
    batch_y0, batch_t, batch_y, batch_y_exog = get_batch()
    pred_y = odeint_adjoint(rhs, batch_y0, batch_y_exog, batch_t, method='euler')
    loss = (pred_y - batch_y).pow(2).sum()
    loss.backward()
    optimizer.step()
    for param in rhs.parameters():
        param.data.clamp_(min=1e-1, max=1)
    reference = (rhs.theta - torch.from_numpy(np.array([0.003, 0.3, 1.81, 1.76, 3.5, 8.,
                                                        10., 10., 0.05, 0.02, 0.015, 1.,
                                                        1., 0.0001, 200])) / rhs.s).pow(2).sum().sqrt().item()
    # dist = (rhs.theta - theta_prev).pow(2).sum().sqrt().item()
    print('[%04d]\tloss\t%e\tdistance to solution\t%e' % (iter_n, loss.item(), reference))
# Out:
# [0000]	loss	4.624683e+02	distance to solution	9.803678e-01
# [0001]	loss	3.518761e+02	distance to solution	9.586814e-01
# [0002]	loss	7.231462e+01	distance to solution	9.614479e-01
# [0003]	loss	1.492304e+03	distance to solution	9.697583e-01
# [0004]	loss	1.883998e+02	distance to solution	9.698385e-01
# [0005]	loss	3.761284e+03	distance to solution	9.740205e-01
# [0006]	loss	7.462555e+02	distance to solution	9.818591e-01
# [0007]	loss	5.701252e+03	distance to solution	9.965842e-01
# %%
with torch.no_grad():
    pred_y = odeint_adjoint(rhs, torch.from_numpy(x0[None]), torch.from_numpy(v[:, None, :]), t, method='euler').squeeze(1)

deltas = pred_y[:, 0]
e1qs = pred_y[:, -1]
pqs = []
for delta, e1q, vt, phi in zip(deltas, e1qs, df.v, df.phi):
    vd = vt * np.sin(delta - phi)
    vq = vt * np.cos(delta - phi)
    
    id = (1.76 * e1q - 1.76 * vq - 0.003 * vd) / (0.3 * 1.76 + 0.003 ** 2)
    iq = (0.003 * e1q - 0.003 * vq + 0.3 * vd) / (0.3 * 1.76 + 0.003 ** 2)
    
    p = 22.2 * (vd * id + vq * iq)
    q = 22.2 * (vq * id - vd * iq)
    pqs.append([p, q])
pqs = np.array(pqs)

# %%
plt.plot(df.p)
plt.plot(pqs[:, 0], '--')

# %% [markdown]
# ## Multi-file

# %%
data_size = 150001
batch_time = 1000
batch_size = 10
t = torch.linspace(0, 15, steps=data_size)
df = pd.read_csv('/Users/nickstulov/Downloads/data_0.csv')
df = df.drop_duplicates('t')
df = df.drop(['t'], axis=1)
v = df[['v', 'phi']].values
x0, v0, c, (p0, q0) = get_initial_values(P0=1997.9999999936396,
                                         Q0=967.9249699065775,
                                         V0=1.0,
                                         angle0=0.494677176989154,
                                         theta0=np.array([0.003, 0.3, 1.81, 1.76, 3.5, 8.,
                                                          10., 10., 0.05, 0.02, 0.015, 1.,
                                                          1., 0.0001, 200]))
with torch.no_grad():
    rhs_true = RHSTrue(c)
    true_y2 = odeint_adjoint(rhs_true, torch.from_numpy(x0[None]), torch.from_numpy(v[:, None, :]), t, method='euler').squeeze(1)

# %%
deltas = true_y2[:, 0]
e1qs = true_y2[:, -1]
pqs = []
for delta, e1q, vt, phi in zip(deltas, e1qs, df.v, df.phi):
    vd = vt * np.sin(delta - phi)
    vq = vt * np.cos(delta - phi)
    
    id = (1.76 * e1q - 1.76 * vq - 0.003 * vd) / (0.3 * 1.76 + 0.003 ** 2)
    iq = (0.003 * e1q - 0.003 * vq + 0.3 * vd) / (0.3 * 1.76 + 0.003 ** 2)
    
    p = 22.2 * (vd * id + vq * iq)
    q = 22.2 * (vq * id - vd * iq)
    pqs.append([p, q])
pqs = np.array(pqs)

# %%
plt.plot(df.p.values)
plt.plot(pqs[:, 0], '--')

# %%
torch.__version__
# Out:
# '1.0.1.post2'

# %%
rhs = RHS(c)
rhs.load_state_dict(torch.load('ph_model.pth'))

# %%
with torch.no_grad():
    true_y = odeint_adjoint(rhs, torch.from_numpy(x0[None]), torch.from_numpy(v[:, None, :]), t, method='euler').squeeze(1)

# %%
deltas = true_y[:, 0]
e1qs = true_y[:, -1]
pqs = []
for delta, e1q, vt, phi in zip(deltas, e1qs, df.v, df.phi):
    vd = vt * np.sin(delta - phi)
    vq = vt * np.cos(delta - phi)
    
    id = (1.76 * e1q - 1.76 * vq - 0.003 * vd) / (0.3 * 1.76 + 0.003 ** 2)
    iq = (0.003 * e1q - 0.003 * vq + 0.3 * vd) / (0.3 * 1.76 + 0.003 ** 2)
    
    p = 22.2 * (vd * id + vq * iq)
    q = 22.2 * (vq * id - vd * iq)
    pqs.append([p, q])
pqs = np.array(pqs)

# %%
plt.plot(df.p.values)
plt.plot(pqs[:, 0], '--')

# %%
plt.plot(df.q.values)
plt.plot(pqs[:, 1], '--')
